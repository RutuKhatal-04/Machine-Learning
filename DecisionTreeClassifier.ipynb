# %% [markdown]
# <a href="https://colab.research.google.com/github/RutuKhatal-04/Machine-Learning/blob/main/DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/iris.csv')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data=data['species'].replace({'setosa':0,'virginica':1,'versicolor':2})
data
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: species, Length: 150, dtype: int64

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
x=data[['sepal_length']]
y=data['species']

clf = tree.DecisionTreeClassifier()
clf.fit(x,y)

y=clf.predict(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3dfd22a05def> in <cell line: 3>()
#       1 from sklearn import tree
#       2 from sklearn.model_selection import train_test_split
# ----> 3 x=data[['sepal_length']]
#       4 y=data['species']
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1031             return self._get_values(key)
#    1032
# -> 1033         return self._get_with(key)
#    1034
#    1035     def _get_with(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1071
#    1072         # handle the dup indexing case GH#4246
# -> 1073         return self.loc[key]
#    1074
#    1075     def _get_values_tuple(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
# ...
