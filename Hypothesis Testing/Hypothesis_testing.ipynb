# %% [markdown]
# <a href="https://colab.research.google.com/github/RutuKhatal-04/Machine-Learning/blob/main/Hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hypothesis

# %% [markdown]
# #Type II error
#
# Type II error lead to status quo when a change may be warranted based on the finding
#
# The retention of a false null hypothesis is a type II error
#
# If the null hypothesis is false you are in error in retaining it and correct in rejecting it

# %% [markdown]
# #Sampling error
#
# error can occur often with sampling.
# sampling error isthe difference between the mean of the poppulation and the mean of the sample
# since we dont kniw the mean of population we must estimate variability
# sampling error of the mean have predictible laws
# there are two possible consequences with sampling error Type 1 and type 2 errors
# type 1 error:
#
# You declare that there is a relationship between your dependent and independent variables.
# Follow-up research shows that your suggested relationships do not actually occur.
# Your results aren't replicated.
# Type I errors lead to changes that are unwarranted. Much more serious than type II.
# The type I error is the rejection of a true null hypothesis.
# If the null hypothesis is true, you are correct in retaining it & in error in rejecting it.
# type 2 error:
#
# You conclude that the difference between two groups is attributed to chance & your null hypothesis is true depending on how you state it.
# Later research rejects your null hypothesis.
# Type II errors lead to status quo when a change may be warranted based on the findings.
# The retention of a false null hypothesis is a type II error.
# If the null hypothesis is false, you are in error in retaining it and correct in rejecting it.

# %% [markdown]
# #Null Hypothesis
#
# Your two choicw in using  a null hypothesis are difference occured by chance or were the result of the relationship between the variables
#
# Remember that the null hypothesis states that there is no actual relationship between variables and that any observed relationship is only a function of chance

# %% [markdown]
# #Level Of Significance
#
# You shoul establish a predetermined level of significance below whihc you will reject the null hypothesis

# %% [markdown]
# # T-Test

# %% [markdown]
# Can be used as an inferential method to compare the mean of the sample to population mean of the sample to the population mean using z-score and the normal probablity curve
#
# You use t-curves for various degree of freedom associated with yourr data
#
# Degree of freedom are the number of observation that vary around a constant
#
# You can only compare two means with the T-test

# %% [markdown]
# #ANOVA
#
#
# Analysis of variance is a ratio of observed difference between more than two means
#
# It is more versatile than a T test and should be used in most cases in .....

# %% [markdown]
# #Chi - Square

# %% [markdown]
# An index used to find the significance of difference between the proportions of subjects , events , object that can be stratified into different categories
#
# Compares observed to expected frequencies.

# %% [markdown]
# ![Screenshot 2024-07-09 085243.png](data:image/png;base64,...)![Screenshot 2024-07-09 085305.png](data:image/png;base64,...)

# %%
 import matplotlib.pyplot as plt
 plt.figure(figsize=(5, 3))

# %%
plt.bar([0, 1, 2, 3], [1/8, 3/8, 3/8, 1/8], width=0.9)
# Out:
# <BarContainer object of 4 artists>

# %%
 _ = plt.xticks([0, 1, 2, 3], [0, 1, 2, 3])

# %%
 plt.xlabel("Distribution of the number of head over 3 flip under the null␣→hypothesis")
# Out:
# Text(0.5, 0, 'Distribution of the number of head over 3 flip under the null␣→hypothesis')

# %%
# 3. Compute the probability (p-value) to observe a value larger or equal that 2 under the null

#  hypothesis ? This probability is the p-value:
#  P(x ≥2|H0) = P(x = 2)+P(x =3)=3 8+1 8=4 8=1 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d84771f247b8> in <cell line: 1>()
# ----> 1 Text(0.5, 0, 'Distribution of the number of head over 3 flip under the null␣→hypothesis')
#
# NameError: name 'Text' is not defined

# %% [markdown]
# ![Screenshot 2024-07-09 091056.png](data:image/png;base64,...)

# %%
 import numpy as np
 import scipy.stats
 succes = np.linspace(30, 70, 41)
 plt.plot(succes, scipy.stats.binom.pmf(succes, 100, 0.5),
 'b-', label="Binomial(100, 0.5)")
 upper_succes_tvalues = succes[succes > 60]
 plt.fill_between(upper_succes_tvalues, 0,
 scipy.stats.binom.pmf(upper_succes_tvalues, 100, 0.5),
 alpha=.8, label="p-value")
 _ = plt.legend()
 pval = 1- scipy.stats.binom.cdf(60, 100, 0.5)
 print(pval)
# Out:
# 0.01760010010885238

# %%
str="Afefa"
a=[]
for i in range(len(s)):
  for j in range(i+1,len(s)):
    a.append(str[i:j])
print(a)
# Out:
# ['A', 'Af', 'Afe', 'Afef', 'f', 'fe', 'fef', 'e', 'ef', 'f']
