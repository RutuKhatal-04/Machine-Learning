# %% [markdown]
# <a href="https://colab.research.google.com/github/RutuKhatal-04/Machine-Learning/blob/main/Sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SAMPLING

# %% [markdown]
# Probablity sampling is also called as random sampling.

# %% [markdown]
# When random sampling is used ,each element in the population has an equal chance of being chosen (Simple random sampling) or known probablity of being selected(Stratified random sampling)

# %% [markdown]
# Stratified random sampling
# The population is divided into groups or strata. A random sample is selected from each stratum based upon the percentage that each subgroup represents in the population . Stratified random samples are generally more accurate in representing the population than are simple random samples

# %% [markdown]
# Convenience Sampling
# Convenience samples are non probablity samples. Therfore it is not possible to specify the probablity of any population elements being selected for the sample. Indeed it is not possible to specify the population from which the samples was drawn

# %% [markdown]
# Quota sampling
# With the quota sampling procedure,we first decide which subgroups of the population interest us.

# %% [markdown]
# ![Screenshot 2024-07-04 131926.png](data:image/png;base64,...)

# %% [markdown]
# If we are representing population Descriptive statisctic we represent it as greek alphabets
# If we represent sample descriptive statistics we represent it by small letters

# %% [markdown]
# To select a random sample using simple random sampling method we should
# follow the steps given below:
#
# i) Determine the population size (N).
#
# ii) Determine the sample size (n).
#
# iii) Number each member of the population under investigation in serial order.
# Suppose there are 100 members number them from 00 to 99.
#
# iv) Determine the starting point of selecting sample by randomly picking up a
# page from random number tables and dropping your finger on the page
# blindly.
#
# v) Choose the direction in which you want to read the numbers (from left to
# right, or right to left, or down or up).
#
# vi) Select the first ‘n’ numbers whose X digits are between 0 and N. If N =
# 100 then X would be 2, if N is a four digit number then X would be 3 and
# so on.
#
# vii) Once a number is chosen, do not use it again.
#
# viii) If you reach the end point of the table before obtaining ‘n’ numbers, pick
# another starting point and read in a different direction and then use the
# first X digit instead of the last X digits and continue until the desired
# sample is selected.

# %% [markdown]
# ![Screenshot 2024-07-04 133911.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-04 133941.png](data:image/png;base64,...)

# %% [markdown]
# #Disproportionate Stratified Samples

# %% [markdown]
# ![Screenshot 2024-07-04 135019.png](data:image/png;base64,...)
