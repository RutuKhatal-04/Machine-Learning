# %% [markdown]
# <a href="https://colab.research.google.com/github/RutuKhatal-04/Machine-Learning/blob/main/Hypothesis_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A company manufacturing RAM chips claims the defective
# rate of the population is 5%. Let p denote the true defective
# probability. We want to test if:
# • H0 : p = 0.05
# • H1 : p > 0.05
# We are going to use a sample of 100 chips from the
# production to test.

# %% [markdown]
# pessimistic
# here not used pessimistic
# pessimistic(what is false we try to prove it and place it in alternate hypothesis)
# but here it is in null hypothesis

# %% [markdown]
# ![Screenshot 2024-07-15 084442.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 084848.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 085227.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 085903.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 085936.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 090543.png](data:image/png;base64,...)![Screenshot 2024-07-15 090601.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 091302.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 091802.png](data:image/png;base64,...)![Screenshot 2024-07-15 091827.png](data:image/png;base64,...)![Screenshot 2024-07-15 091834.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 092426.png](data:image/png;base64,...)![Screenshot 2024-07-15 092434.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 092706.png](data:image/png;base64,...)![Screenshot 2024-07-15 092652.png](data:image/png;base64,...)![Screenshot 2024-07-15 092714.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 093136.png](data:image/png;base64,...)![Screenshot 2024-07-15 093155.png](data:image/png;base64,...)![Screenshot 2024-07-15 093144.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 094658.png](data:image/png;base64,...)![Screenshot 2024-07-15 094649.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 094714.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-15 102705.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 082659.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 093044.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 093702.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 094217.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 094235.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 094244.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 095526.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 095544.png](data:image/png;base64,...)![Screenshot 2024-07-16 095556.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105638.png](data:image/png;base64,...)![Screenshot 2024-07-16 105647.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105656.png](data:image/png;base64,...)![Screenshot 2024-07-16 105717.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105724.png](data:image/png;base64,...)![Screenshot 2024-07-16 105731.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105742.png](data:image/png;base64,...)![Screenshot 2024-07-16 105755.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105808.png](data:image/png;base64,...)![Screenshot 2024-07-16 105838.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105852.png](data:image/png;base64,...)![Screenshot 2024-07-16 105906.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105923.png]()![Screenshot 2024-07-16 105916.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-16 105923.png](data:image/png;base64,...)

# %% [markdown]
# #T TEST FOR ONE SAMPLE

# %%
import numpy as np
from scipy import stats

student_scores=np.array([72,89,65,73,79,84,63,76,85,75])

#Hypothesized Poupulation mean
mu=70
#Perform one-sample t-test
t_stat,p_value=stats.ttest_1samp(student_scores,mu)
print("t-statistic:",t_stat)
print("p-value:",p_value)

#Setting significance level
alpha=0.05

#Interpret the result
if p_value<alpha:
    print("Reject the null hypothesis there is significant difference betwn sample mean and hypothesized mean")
else:
    print("Accept the null hypothesis there is no significant difference betwn sample mean and hypothesized mean")
# Out:
# t-statistic: 2.2894683580127317
# p-value: 0.047816221110566944
# Reject the null hypothesis

# %% [markdown]
# #T TEST FOR 2 SAMPLE

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Filter the dataset for the two species we want to compare:
setosa=iris[iris['species']=='setosa']
versicolor=iris[iris['species']=='versicolor']

#Extract the petal lengths for each species :

setosa_petal_length=setosa['petal_length']
versicolor_petal_length=versicolor['petal_length']

#Perform the t-test
t_stat,p_value=stats.ttest_ind(setosa_petal_length,versicolor_petal_length)
print("t-statistic:",t_stat)
print("p-value:",p_value)

#Setting significance level
alpha=0.05

#Interpret the result
if p_value<alpha:
    print("Reject the null hypothesis there is significant difference betwn sample mean")
else:
    print("Accept the null hypothesis there is no significant difference betwn sample mean")
# Out:
# t-statistic: -39.492719391538095
# p-value: 5.404910513441677e-62
# Reject the null hypothesis there is significant difference betwn sample mean

# %% [markdown]
# ##Check data assumption : Ensure that your data meets the assumption of the t test before proceeding with the analysis .

# %%
#Filter the dataset for the two species we want to compare:
setosa=iris[iris['species']=='setosa']
versicolor=iris[iris['species']=='versicolor']

#Extract the petal lengths for each species :

setosa_petal_length=setosa['petal_width']
versicolor_petal_length=versicolor['petal_width']

#Perform the t-test
t_stat,p_value=stats.ttest_ind(setosa_petal_length,versicolor_petal_length)
print("t-statistic:",t_stat)
print("p-value:",p_value)

#Setting significance level
alpha=0.05

#Interpret the result
if p_value<alpha:
    print("Reject the null hypothesis there is significant difference betwn sample mean")
else:
    print("Accept the null hypothesis there is no significant difference betwn sample mean")
# Out:
# t-statistic: -34.08034154357719
# p-value: 3.831095388248162e-56
# Reject the null hypothesis there is significant difference betwn sample mean

# %%
#Filter the dataset for the two species we want to compare:
virginica=iris[iris['species']=='virginica']
versicolor=iris[iris['species']=='versicolor']

#Extract the petal lengths for each species :

virginica_petal_length=virginica['petal_width']
versicolor_petal_length=versicolor['petal_width']

#Perform the t-test
t_stat,p_value=stats.ttest_ind(virginica_petal_length,versicolor_petal_length)
print("t-statistic:",t_stat)
print("p-value:",p_value)

#Setting significance level
alpha=0.05

#Interpret the result
if p_value<alpha:
    print("Reject the null hypothesis there is significant difference betwn sample mean")
else:
    print("Accept the null hypothesis there is no significant difference betwn sample mean")
# Out:
# t-statistic: 14.625367047410148
# p-value: 2.2304090710248333e-26
# Reject the null hypothesis there is significant difference betwn sample mean

# %%
#Filter the dataset for the two species we want to compare:
virginica=iris[iris['species']=='virginica']
setosa=iris[iris['species']=='setosa']

#Extract the petal lengths for each species :

virginica_petal_length=virginica['petal_length']
setosa_petal_length=versicolor['petal_length']

#Perform the t-test
t_stat,p_value=stats.ttest_ind(virginica_petal_length,setosa_petal_length)
print("t-statistic:",t_stat)
print("p-value:",p_value)

#Setting significance level
alpha=0.05

#Interpret the result
if p_value<alpha:
    print("Reject the null hypothesis there is significant difference betwn sample mean")
else:
    print("Accept the null hypothesis there is no significant difference betwn sample mean")
# Out:
# t-statistic: 12.603779441384985
# p-value: 3.1788195478061495e-22
# Reject the null hypothesis there is significant difference betwn sample mean
