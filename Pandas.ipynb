# %% [markdown]
# <a href="https://colab.research.google.com/github/RutuKhatal-04/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas is used for file handling
# It expect to have data in tables

# %%
from pandas import Series,DataFrame
import pandas as pd

# %%
s1=Series(range(0,4))
s6=Series(range(1,5))

# %%
s2=Series(['a','b'])
s3=Series(['c','d'])
s4=s2+s3
s7=s1+s6
print(s7)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
print(s4)
# Out:
# 0    ac
# 1    bd
# dtype: object

# %%
s5=Series(['a','b'])*3

# %%
print(s5)
# Out:
# 0    aaa
# 1    bbb
# dtype: object

# %%
import pandas as pd
data=pd.read_csv('/content/sample_data/california_housing_train.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
idx=data.columns
print(idx)
idx1=data.index
print(idx1)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# RangeIndex(start=0, stop=17000, step=1)

# %%
#some index attributes
b=idx.is_monotonic_decreasing
print(b)
c=idx.is_monotonic_increasing
print(c)
e=idx.has_duplicates
print(e)
i=idx.nlevels
print(i)
# Out:
# False
# False
# False
# 1

# %%
#Some index Methods

# %%
A=idx.values #get as numpy array
print(A)
l=idx.tolist() #get as list
print(l)
# idx=idx.astype(int)#change datatype
# print(idx)
# Out:
# ['longitude' 'latitude' 'housing_median_age' 'total_rooms'
#  'total_bedrooms' 'population' 'households' 'median_income'
#  'median_house_value']
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# %%
b=idx.equals(0) #check for equality
print(b)
# Out:
# False

# %%
idx=idx.union(idx1) #union of two index

# %%
i=idx.nunique()#number unique labels
print(i)
label=idx.min() #minimumm label
print(label)
label=idx.max()
print(label)
# Out:
# 9
# households
# total_rooms

# %%
#From inline CSV text to a DataFrame
from io import StringIO
data = """, Animal, Cuteness, Desirable
row-1, dog, 8.7, True
row-2, cat, 9.5, True
row-3, bat, 2.6, False"""
df = pd.read_csv(StringIO(data), header=0,
 index_col=0, skipinitialspace=True)
# """ .....""" its docstring to keep multiple line in one line
print(df)
# Out:
#       Animal  Cuteness  Desirable
# row-1    dog       8.7       True
# row-2    cat       9.5       True
# row-3    bat       2.6      False

# %%
# Each Excel sheet in a Python dictionary
workbook = pd.ExcelFile('pandas.xlsx')
d = {} # start with an empty dictionary
for sheet_name in workbook.sheet_names:
 df = workbook.parse(sheet_name)
 d[sheet_name] = df

print(d)

# %%
#Data in series then combine into a dataframe
s1=Series({'Tom':1,'Dick':2,'Har':3})
s2=Series({'Tom':3,'Dick':2,'Har':1})
s4=pd.concat({'A':s3,'B':s4},axis=0)
print(s1.index)
print(s1.values)
print(s4)
# Out:
# Index(['Tom', 'Dick', 'Har'], dtype='object')
# [1 2 3]
# A  0     c
#    1     d
# B  0    ac
#    1    bd
# dtype: object

# %%
import pandas as pd
data=pd.read_csv('/content/sample_data/california_housing_train.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
n=4
dfh=data.head(n)
dfh
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0

# %%
dft=data.tail(n)
dft
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
dfs=data.describe()
dfs
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
top_left_count_df=data.iloc[:5,:5]
#will show 5 rows and 5 columns
top_left_count_df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (17000, 9)

# %%
dft=data.T #transpose rows and cols
dft
# Out:
#                          0         1           2           3          4      \
# longitude            -114.3100   -114.47   -114.5600   -114.5700   -114.570
# latitude               34.1900     34.40     33.6900     33.6400     33.570
# housing_median_age     15.0000     19.00     17.0000     14.0000     20.000
# total_rooms          5612.0000   7650.00    720.0000   1501.0000   1454.000
# total_bedrooms       1283.0000   1901.00    174.0000    337.0000    326.000
# population           1015.0000   1129.00    333.0000    515.0000    624.000
# households            472.0000    463.00    117.0000    226.0000    262.000
# median_income           1.4936      1.82      1.6509      3.1917      1.925
# median_house_value  66900.0000  80100.00  85700.0000  73400.0000  65500.000
#
#                          5           6           7           8      \
# longitude            -114.5800   -114.5800   -114.5900   -114.5900
# latitude               33.6300     33.6100     34.8300     33.6100
# ...

# %%
l=data.axes #list rows adn col indexs
l
# Out:
# [RangeIndex(start=0, stop=17000, step=1),
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value'],
#        dtype='object')]

# %%
(r,c)=data.axes # from above
r
print(c)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
s=data.dtypes #Series column data types
s
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.values)
# Out:
# numpy.ndarray

# %%
#dataframe utility methods
dfc=data.copy() #copy a dataframe
dfc
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
dfr=data.rank() #rank each row (default)
dfr
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        17000.0    8063.0              2517.5      15885.0         16149.0
# 1        16999.0    8855.0              4620.5      16493.0         16732.5
# 2        16998.0    1974.5              3648.5       1041.5          1292.0
# 3        16996.5    1766.5              2136.0       4524.5          5517.0
# 4        16996.5    1591.0              5018.0       4209.0          5180.0
# ...          ...       ...                 ...          ...             ...
# 16995        5.0   16802.0             16474.5       8970.5          7308.0
# 16996        4.0   16843.5             12167.0       9668.0         10761.5
# 16997        2.5   16994.0              3648.5      11142.5         10812.0
# 16998        2.5   16989.5              4620.5      11119.5         11209.0
# 16999        1.0   16771.0             16474.5       6652.0          4347.0
#
# ...

# %%
dfs=data['longitude'].sort_values() #sort each col(default)
dfs
dfc=data.astype('string') #type conversion
dfc
# Out:
#       longitude latitude housing_median_age total_rooms total_bedrooms  \
# 0       -114.31    34.19               15.0      5612.0         1283.0
# 1       -114.47     34.4               19.0      7650.0         1901.0
# 2       -114.56    33.69               17.0       720.0          174.0
# 3       -114.57    33.64               14.0      1501.0          337.0
# 4       -114.57    33.57               20.0      1454.0          326.0
# ...         ...      ...                ...         ...            ...
# 16995   -124.26    40.58               52.0      2217.0          394.0
# 16996   -124.27    40.69               36.0      2349.0          528.0
# 16997    -124.3    41.84               17.0      2677.0          531.0
# 16998    -124.3     41.8               19.0      2672.0          552.0
# 16999   -124.35    40.54               52.0      1820.0          300.0
#
#       population households median_income median_house_value
# ...

# %%
#Saving a Dataframe to a csv file
data.to_csv('name.csv')

# %%
from pandas import ExcelWriter
writer=ExcelWriter('pandas1.xlsx')
data.to_excel(writer,'Sheet1')
data.to_excel(writer,'Sheet2')
writer.close()

# %%
#Get column index and labels
idx=data.columns # get col index
print(idx)
label=data.columns[0] #1st col index
print(label)
lst=data.columns.tolist()#get as a list
print(lst)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# longitude
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# %%
#Change column labels
data.rename(columns={'old':'new'},inplace=True)
data=data.rename(columns={'a':1,'b':'x'})
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#Selecting Columns
s=data['longitude'] #Select col to Series
print(s)
s1=data[['longitude']] #Select col to df
print(s1)
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64
#        longitude
# 0        -114.31
# 1        -114.47
# 2        -114.56
# 3        -114.57
# 4        -114.57
# ...          ...
# 16995    -124.26
# 16996    -124.27
# 16997    -124.30
# 16998    -124.30
# 16999    -124.35
#
# [17000 rows x 1 columns]

# %%
#Selecting columns with python attributes
s=data.latitude
print(s)
# Out:
# 0        34.19
# 1        34.40
# 2        33.69
# 3        33.64
# 4        33.57
#          ...
# 16995    40.58
# 16996    40.69
# 16997    41.84
# 16998    41.80
# 16999    40.54
# Name: latitude, Length: 17000, dtype: float64

# %%
#cannot create new columns by attribute
data.population=data.latitude/data.longitude
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#Adding new columns to a Dataframe
data['new_column1']=data.latitude/data.longitude
# data['new_column']=range(len(data))
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# Assuming 'data' is your DataFrame
data = data[['longitude', 'latitude'] + [col for col in data.columns if col not in ['longitude', 'latitude']]]
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
#Droping Columns
data=data.drop('longitude',axis=1,inplace=True)
data
